# %%
print('hello')
# Out:
# hello

# %%
# Machine Learning 
# 1. Youtube Recommendation-> learn from your watch history
# 2.Spam Detection in Gmail->Learn pattern in spam emails
# 3. Voice Assistants(Siri ,Alexa)->learn how you speak 
# 4. Self-Driving Cars->Learn to identify stop signs,
# 5.pedestrians and road
# 6.Face Unlock on Phone ->Learn to recognize to you face

             #Traditional Programming 
             
# Give rules +data->get result
         
           #Machine Learning
           #Given data +result-> get rules(model) 
           # learn patterns automatically

# %%
# AI vs ML vs DL
# AI-Artificial Intelligence is the big umbrella
# -its the science of making 
# machine smart ,just like human

# Ai is the big picutre
# ml is the brain learn data
# deep leaning is the super power lean data

# %%
            # Type of Machine Learning
            
# Supervised Learning is like a student being taught by a teacher .
# We give the machine input and the correct answer and it learns to predit 

          #  Supervised Learning
          #Supervised Learning is a type of Machine Learning where a model 
          #learns from labeled data, meaning the input data is provided along
          # with the correct output, and then it predicts the output for new data.
          #Jab hum machine ko input ke saath correct output bhi dete hain, aur machine
          # un examples se pattern seekhkar naye data ka output predict karti hai,
          # use Supervised Learning kehte hain.
          
         # pattern Supervised = Data + Answer → Learning → Prediction

# %%
    #   Unsupervised Learning 

# Unsupervised Learning is a type of Machine Learning 
# where the model learns from unlabeled data and
# identifies hidden patterns, structures, or groups in
# the data without predefined output labels.


# Uvesh, Unsupervised Learning bhi Machine Learning
# ka ek type hai. Isme machine ko correct answer/label
# nahi diya jata. Machine khud data ke andar patterns aur
# groups find karti hai.

# %%
       # Reinforcement Learning
       #Reinforcement Learning is a type of Machine Learning where 
       # an agent learns by interacting with an environment and 
       # receiving rewards or penalties for its actions.
       # The goal is to maximize the total reward over time.
       # Reinforcement Learning mein machine/agent khud actions try 
       # karta hai aur action ke result ke according usko:

# %%
# EDA

# let see the steps involved in making a machine learning model.
# 1.problem definition
# 2.Data Collection
# 3.Exploratory Data Analysis(EDA)
# 4.Data Preprocessing/Cleaning 
# 5.Feature Selection & Engineering 
# 6.Split the Dataset
# 7.Model Section
# 8.Model Training
# 9.Model Evaluation
# 10.Hyperparameter Tuning
# 11. Model testing /Validation

# %%
# Data Preposition
#Uvesh, Data Preprocessing ka matlab hota hai raw data ko clean aur ML model ke liye ready karna.

# %%
#Uvesh, Feature Engineering ka matlab hota hai existing data se
# useful features banana ya existing features ko modify karna,
# taaki Machine Learning model better prediction kar sake.

# %%
           # Headmap
           
# Uvesh, agar tum Heatmap ki baat kar rahe ho,
# to iska use data ke values aur relationships
# ko colors ke through easily samajhne ke liye hota hai.


#          # eda

# Uvesh, EDA (Exploratory Data Analysis) ka main kaam hota
# hai dataset ko samajhna aur uske andar
# problems/patterns find karna,
# ML model banane se pehle.

# %%
# Data cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
df=pd.read_csv(r"C:\Users\Dell\Downloads\insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# EDA

df.shape
# Out:
# (1338, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
numeric_colums=['age','bmi','children','charges']

for col in numeric_colums:
    plt.figure(figsize=(15,5))
    sns.histplot(df[col],kde=True,bins=20)

# %%
sns.countplot(x=df['children'])
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(x=df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(y=df['bmi'])
# Out:
# <Axes: xlabel='count', ylabel='bmi'>

# %%
sns.countplot(x=df['smoker'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
import matplotlib.pyplot as plt


for col in numeric_colums:
    plt.figure(figsize=(15,5))
    sns.boxplot(x=df[col])

# %%
sns.countplot(x=df['bmi'])
# Out:
# <Axes: xlabel='bmi', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
# Data Cleaning and prperocessing

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df_clean=df.copy()

# %%
df_clean
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_clean
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_clean.shape
# Out:
# (1338, 7)

# %%
df_clean.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_clean.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df_clean.drop_duplicates(inplace=True)

# %%
df_clean
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df_clean.shape
# Out:
# (1337, 7)

# %%
df_clean.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df_clean['sex'].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
df_clean['sex']=df_clean['sex'].map({"male":0,"female":1})

# %%
df_clean
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    1  27.900         0    yes  southwest  16884.92400
# 1      18    0  33.770         1     no  southeast   1725.55230
# 2      28    0  33.000         3     no  southeast   4449.46200
# 3      33    0  22.705         0     no  northwest  21984.47061
# 4      32    0  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    0  30.970         3     no  northwest  10600.54830
# 1334   18    1  31.920         0     no  northeast   2205.98080
# 1335   18    1  36.850         0     no  southeast   1629.83350
# 1336   21    1  25.800         0     no  southwest   2007.94500
# 1337   61    1  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df_clean['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
df_clean['smoker']=df_clean['smoker'].map({'yes':1,'no':0})

# %%
df_clean
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    1  27.900         0       1  southwest  16884.92400
# 1      18    0  33.770         1       0  southeast   1725.55230
# 2      28    0  33.000         3       0  southeast   4449.46200
# 3      33    0  22.705         0       0  northwest  21984.47061
# 4      32    0  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    0  30.970         3       0  northwest  10600.54830
# 1334   18    1  31.920         0       0  northeast   2205.98080
# 1335   18    1  36.850         0       0  southeast   1629.83350
# 1336   21    1  25.800         0       0  southwest   2007.94500
# 1337   61    1  29.070         0       1  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df_clean['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
df_clean.rename(columns={
    'sex':'is_female',
    'smoker':'is_smoker'
},inplace=True)

# %%
df_clean
# Out:
#       age  is_female     bmi  children  is_smoker     region      charges
# 0      19          1  27.900         0          1  southwest  16884.92400
# 1      18          0  33.770         1          0  southeast   1725.55230
# 2      28          0  33.000         3          0  southeast   4449.46200
# 3      33          0  22.705         0          0  northwest  21984.47061
# 4      32          0  28.880         0          0  northwest   3866.85520
# ...   ...        ...     ...       ...        ...        ...          ...
# 1333   50          0  30.970         3          0  northwest  10600.54830
# 1334   18          1  31.920         0          0  northeast   2205.98080
# 1335   18          1  36.850         0          0  southeast   1629.83350
# 1336   21          1  25.800         0          0  southwest   2007.94500
# 1337   61          1  29.070         0          1  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df_clean['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
df_clean['region']=df_clean['region'].map({
   
    
})

# %%
df_clean['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
df_clean=pd.get_dummies(df_clean,columns=['region'],drop_first=True)

# %%
df_clean
# Out:
#       age  is_female     bmi  children  is_smoker      charges  \
# 0      19          1  27.900         0          1  16884.92400
# 1      18          0  33.770         1          0   1725.55230
# 2      28          0  33.000         3          0   4449.46200
# 3      33          0  22.705         0          0  21984.47061
# 4      32          0  28.880         0          0   3866.85520
# ...   ...        ...     ...       ...        ...          ...
# 1333   50          0  30.970         3          0  10600.54830
# 1334   18          1  31.920         0          0   2205.98080
# 1335   18          1  36.850         0          0   1629.83350
# 1336   21          1  25.800         0          0   2007.94500
# 1337   61          1  29.070         0          1  29141.36030
#
#       region_northwest  region_southeast  region_southwest
# 0                False             False              True
# 1                False              True             False
# ...

# %%
df_clean=df_clean.astype(int)

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_clean.dtypes
# Out:
# age                 int64
# is_female           int64
# bmi                 int64
# children            int64
# is_smoker           int64
# charges             int64
# region_northwest    int64
# region_southeast    int64
# region_southwest    int64
# dtype: object

# %%
# feature engineering and Extraction

# %%
df_clean
# Out:
#       age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0      19          1   27         0          1    16884                 0
# 1      18          0   33         1          0     1725                 0
# 2      28          0   33         3          0     4449                 0
# 3      33          0   22         0          0    21984                 1
# 4      32          0   28         0          0     3866                 1
# ...   ...        ...  ...       ...        ...      ...               ...
# 1333   50          0   30         3          0    10600                 1
# 1334   18          1   31         0          0     2205                 0
# 1335   18          1   36         0          0     1629                 0
# 1336   21          1   25         0          0     2007                 0
# 1337   61          1   29         0          1    29141                 1
#
#       region_southeast  region_southwest
# ...

# %%
df_clean
# Out:
#       age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0      19          1   27         0          1    16884                 0
# 1      18          0   33         1          0     1725                 0
# 2      28          0   33         3          0     4449                 0
# 3      33          0   22         0          0    21984                 1
# 4      32          0   28         0          0     3866                 1
# ...   ...        ...  ...       ...        ...      ...               ...
# 1333   50          0   30         3          0    10600                 1
# 1334   18          1   31         0          0     2205                 0
# 1335   18          1   36         0          0     1629                 0
# 1336   21          1   25         0          0     2007                 0
# 1337   61          1   29         0          1    29141                 1
#
#       region_southeast  region_southwest
# ...

# %%
sns.histplot(df['bmi'])
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
df_clean['bmi_category']=pd.cut(
    df_clean['bmi'],
    bins=[0,18.5,24.9,29.9,float('inf')],
    
    labels=['Underweight','Normal','Overweight','Obese']
    
)

# %%
df_clean
# Out:
#       age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0      19          1   27         0          1    16884                 0
# 1      18          0   33         1          0     1725                 0
# 2      28          0   33         3          0     4449                 0
# 3      33          0   22         0          0    21984                 1
# 4      32          0   28         0          0     3866                 1
# ...   ...        ...  ...       ...        ...      ...               ...
# 1333   50          0   30         3          0    10600                 1
# 1334   18          1   31         0          0     2205                 0
# 1335   18          1   36         0          0     1629                 0
# 1336   21          1   25         0          0     2007                 0
# 1337   61          1   29         0          1    29141                 1
#
#       region_southeast  region_southwest bmi_category
# ...

# %%
df_clean=pd.get_dummies(df_clean,columns=['bmi_category'],drop_first=True)

# %%
df_clean=df_clean.astype(int)

# %%
df_clean
# Out:
#       age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0      19          1   27         0          1    16884                 0
# 1      18          0   33         1          0     1725                 0
# 2      28          0   33         3          0     4449                 0
# 3      33          0   22         0          0    21984                 1
# 4      32          0   28         0          0     3866                 1
# ...   ...        ...  ...       ...        ...      ...               ...
# 1333   50          0   30         3          0    10600                 1
# 1334   18          1   31         0          0     2205                 0
# 1335   18          1   36         0          0     1629                 0
# 1336   21          1   25         0          0     2007                 0
# 1337   61          1   29         0          1    29141                 1
#
#       region_southeast  region_southwest  bmi_category_Normal  \
# ...

# %%
df_clean
# Out:
#       age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0      19          1   27         0          1    16884                 0
# 1      18          0   33         1          0     1725                 0
# 2      28          0   33         3          0     4449                 0
# 3      33          0   22         0          0    21984                 1
# 4      32          0   28         0          0     3866                 1
# ...   ...        ...  ...       ...        ...      ...               ...
# 1333   50          0   30         3          0    10600                 1
# 1334   18          1   31         0          0     2205                 0
# 1335   18          1   36         0          0     1629                 0
# 1336   21          1   25         0          0     2007                 0
# 1337   61          1   29         0          1    29141                 1
#
#       region_southeast  region_southwest  bmi_category_Normal  \
# ...
