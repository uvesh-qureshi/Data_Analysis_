# %%
# def goodDay(name):
#     print('Good Day')
# goodDay("uvesh")
# Out:
# Good Day

# %%
def goodDay(name,ending):
    print('Good day'," "+ name,ending)
    return 'done'
goodDay('uvesh','qureshi')
a=goodDay('rohan','qureshi')

print(a)
# Out:
# Good day  uvesh qureshi
# Good day  rohan qureshi
# done

# %%
def goodDay(name,ending='thank you'):
    print(f'good day,{name}')
    print(ending)
    
goodDay('uvesh','thankyou')
# Out:
# good day,uvesh
# thankyou

# %%
f=open('file.txt')
data=f.read()
print(data)
f.close()
# Out:
# hello sir uiasiutyopkioiojio

# %%
                         # file write

# %%
st='hey harry you are amazing wuysdfgyuuyyu'

f=open('uvesh.txt','w')
f.write(st)
f.close()

# %%
f=open('file.txt')
lines=f.readlines()
print(lines,type(lines))
f.close()
# Out:
# ['harry is a good boy \n', 'i m a second line \n', 'this is a amazing\n', 'twinke twinkle little start '] <class 'list'>

# %%
with open('file.txt') as f:
    
    print(f.read())
# Out:
# harry is a good boy
# i m a second line
# this is a amazing
# twinke twinkle little start
