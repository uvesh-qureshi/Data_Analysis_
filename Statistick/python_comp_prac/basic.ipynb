# %%
print('chai or code')
# Out:
# chai or code

# %%
mylist=[1,2,4,5,[2,4,5]]
print(mylist)
# Out:
# [1, 2, 4, 5, [2, 4, 5]]

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %%
a='32.1'
b=float(a)
t=type(b)
print(type(t))
print(t)
# Out:
# <class 'type'>
# <class 'float'>

# %%
a=int(input('enter the first number'))
b=int(input('enter the second number'))

print("first number is:",a)
print("second number is:",b)
print("sum is :",a+b)
# Out:
# first number is: 34
# second number is: 34
# sum is : 68

# %%
name='uveshqureshi'

namecount=name[0:4]
print(namecount)
char=name[1]
print(char)
# Out:
# uves
# v

# %%
name='uveshqureshi'
print(name[0:3])
print(name[-4:-1])
print(name[-4:-1])
print(name[1:4])
# Out:
# uve
# esh
# esh
# ves

# %%
word='amazing'
print(word[1:6:2])
# Out:
# mzn

# %%
a='0123456789'
print(a[1:7:3])
# Out:
# 14

# %%
name='harry'
print(len(name))
print(name.endswith('rry'))
print(name.startswith('har'))
print(name.capitalize())
print(name.upper())
print(name.count('r'))
print(name.replace('harry','uvesh'))
# Out:
# 5
# True
# True
# Harry
# HARRY
# 2
# uvesh

# %%
a=['apple','Orange',5,555.5,False,'akash','rohan']
a[0]='uvesh'
a.append('tarun')
print(a[0])
print(a)
# Out:
# uvesh
# ['uvesh', 'Orange', 5, 555.5, False, 'akash', 'rohan', 'tarun']

# %%
l=[1,34,62,2,6,11]
# l.sort()
# l.reverse()
# li.insert(333,3)
# # l.insert(3,45)
# l.pop(2)
# l.pop()
# l.pop()
l.remove(34)
print(l)
# Out:
# [1, 62, 2, 6, 11]

# %%
# inmutab data in python

# %%
a=(1,2,3,4)
print(type(a))
print(a)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4)

# %%
a=(1,45,343,3434,False,45,'Rohan',49)
no=a.count(45)
print(no)
# Out:
# 2

# %%
i=a.index(49)
print(i)
# Out:
# 7

# %%
my_tuple=(1,2,3)
print(3 in my_tuple)
print(1 in my_tuple)
# Out:
# True
# True

# %%
my_tuple=(1,2,3)
repeated=my_tuple*3
print(repeated)
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
slice=(1,2,3,4,5,6)
sliced=slice[1:4]
print(sliced)
# Out:
# (2, 3, 4)

# %%
mark={
      'Harry':100,
      'shubham':56,
      'Rohan':34
      
  }
print(mark)
print(type(mark))
print(mark['Harry'])
print(mark.items())
print(mark.keys())
print(mark.values())

mark.update({'Harry':99})
print(mark)
a=mark.clear()
print(a)
# Out:
# {'Harry': 100, 'shubham': 56, 'Rohan': 34}
# <class 'dict'>
# 100
# dict_items([('Harry', 100), ('shubham', 56), ('Rohan', 34)])
# dict_keys(['Harry', 'shubham', 'Rohan'])
# dict_values([100, 56, 34])
# {'Harry': 99, 'shubham': 56, 'Rohan': 34}
# None

# %%
student = {
    "name": "Uvesh",
    "age": 21,
    "course": "B.Tech"
}
# student.pop('age')
# print(student)
student.pop('name')
print(student)
# Out:
# {'age': 21, 'course': 'B.Tech'}

# %%
student = {
    "name": "Uvesh",
    "age": 21,
    "course": "B.Tech"
}
student.popitem()
student
print(student)
# Out:
# {'name': 'Uvesh', 'age': 21}

# %%
d={}
print(type(d))
# Out:
# <class 'dict'>

# %%
s=set()
print(type(s))
# Out:
# <class 'set'>

# %%
s={1,4,5,6,8,9,5,}
print(s,type(s))
s.add(4545)
s.add('hello')
print(s,type(s))
# Out:
# {1, 4, 5, 6, 8, 9} <class 'set'>
# {1, 4545, 'hello', 4, 5, 6, 8, 9} <class 'set'>

# %%
# union

s1={7,45,6,85}
s2={7,8,178,89}
print(s1.union(s2))
print(s1.intersection(s2))
# Out:
# {6, 7, 8, 45, 178, 85, 89}
# {7}

# %%
s1={1,23,45}
s2={6,1,3,34,23,54}
s=s1-s2
print(s)
# Out:
# {45}

# %%
s=set()
n=int(input('Enter number1:'))
s.add(int(n))
n=int(input('Enter number2:'))
s.add(int(n))
n=int(input('Enter number3:'))
s.add(int(n))
n=int(input('Enter number4:'))
s.add(int(n))
n=int(input('Enter number4:'))
s.add(int(n))
n=int(input('Enter number5:'))
s.add(int(n))
n=int(input('Enter number5:'))
s.add(int(n))
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s=set()
s.add(18)
s.add('34')

s.add(45)
s.add('56')

s.add(18.0)
print(len(s))
print(s)
# Out:
# 4
# {18, '56', 45, '34'}

# %%
s={}
print(type(s))
# Out:
# <class 'dict'>

# %%
d={}
name=input('Enter the nane :')
language=input('enter the fav language')
d.update({name:language})
name=input('Enter the nane :')
language=input('enter the fav language')
d.update({name:language})
name=input('Enter the nane :')
language=input('enter the fav language')
d.update({name:language})
name=input('Enter the nane :')
language=input('enter the fav language')
d.update({name:language})
print(d)
# Out:
# {'uvesh': 'python', 'qwq': 'er', 'sd': 'gh', 'xc': 'vb'}

# %%
# candition express
a=int(input('enter the age'))
print("age is :",a)
# Out:
# age is : 12

# %%
a=int(input('enter the age'))

if(a>20):
    print('age is succesfull:',a)
    print('good for ')
elif(a<0):
    print('you are the below of zero')
elif(a==100):
    print('number is equal')
    
else:
    print('age is not suceesful:',a)
    print('hello sir')
# Out:
# age is succesfull: 100
# good for

# %%
a=int(input('enter the age'))
# if statement no.1
if(a%2==0):
    print('a is even')
# if statement no:2
if(a>=20):
    print('age is succesfull:')
    print('good for ')
elif(a<0):
    print('you are the below of zero')

    
else:
    print('age is not suceesful:')
    print('hello sir')
# Out:
# a is even
# age is succesfull:
# good for

# %%
# problem no 1

# %%
a1=int(input('enter the number 1: '))
a2=int(input('enter the number 1: '))
a3=int(input('enter the number 1: '))
a4=int(input('enter the number 1: '))
if(a1>a2 and a1>a3 and  a1>a4):
    print('a1 is greater  number is a1:',a1)

elif(a2>a1 and a2>a3 and a2>a4):
    print('Greater then numner is a1:',a2)
    
elif(a3>a1 and a3>a2 and a3>a4):
    print('greater than is a3:',a3)

elif(a4>a1 and a4>a2 and a4>a3):
    print('greater then number is a4:',a4)
# Out:
# greater then number is a4: 4

# %%
# write a program to pass

# %%
mark1=int(input('enter the mark1'))
mark2=int(input('enter the mark 2'))
mark3=int(input('enter the mark3'))
mark4=int(input('enter the mark 4'))

total_percentage=(100*(mark1+mark2+mark3+mark4))/300

if(total_percentage>=40):
    print('you are pass')
else:
    print('you are failed,try again')
# Out:
# you are pass

# %%
p1='Make a lot of money'
p2='Buy now'
p3='subscribe this'
p4='click this'

message=input('enter your comment:')
if((p1 in message )or (p2 in message )or (p3 in message)or (p4 in message)):
    print('this comment is a spam')
else:
    print('this comment is not  a spam')
# Out:
# this comment is a spam

# %%
username=input('enter  username')
if(len(username)<10):
    print('you username container less than 10 charactor')
else:
    print('All is well')
# Out:
# you username container less than 10 charactor

# %%
l=['harry','rohan','shubham','diya']
name=input('enter the name')
if(name in l):
    print('you name is the list')
else:
    print('you name is not list')
# Out:
# you name is the list

# %%
# loop in python

# %%
# 1 to 100 print

for i in range(1,9):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
i=1
while(i<6):
    print('harry:',i)
    i=i+1
# Out:
# harry: 1
# harry: 2
# harry: 3
# harry: 4
# harry: 5

# %%
l=[1,'harry','this','rohan','Shubham','uvesh']
i=0
while(i<len(l)):
    print(l[i])
    i=i+1
# Out:
# 1
# harry
# this
# rohan
# Shubham
# uvesh

# %%
for i in range(0,100,4):
    print(i)
# Out:
# 0
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 44
# 48
# 52
# 56
# 60
# 64
# 68
# 72
# 76
# 80
# 84
# 88
# 92
# 96

# %%
l=[1,2,6,234,6,764]
for i in l:


    print(i)
# Out:
# 1
# 2
# 6
# 234
# 6
# 764

# %%
t=(6,231,75,122)
for i in t:
    print(i)
# Out:
# 6
# 231
# 75
# 122

# %%
s="harry"
for i in s:
    print(i)
# Out:
# h
# a
# r
# r
# y

# %%
l=[1,7,8]
for item in l:
    print(item)
else:
    print('done')
# Out:
# 1
# 7
# 8
# done

# %%
for i in range(1,100):
    if(i==4):
        break
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(4):
    if(i==3):
        continue
    
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(657):
    pass
    
    
i=0
while(i<5):
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n=int(input('enter the number'))
for i in range(1,11):
    print(f"{n} X {i}={n*i}")
# Out:
# 45 X 1=45
# 45 X 2=90
# 45 X 3=135
# 45 X 4=180
# 45 X 5=225
# 45 X 6=270
# 45 X 7=315
# 45 X 8=360
# 45 X 9=405
# 45 X 10=450

# %%
n=int(input('enter the number'))
for i in range(1,n):
    print(f"{n} X {i}={i*n}")
# Out:
# 12 X 1=12
# 12 X 2=24
# 12 X 3=36
# 12 X 4=48
# 12 X 5=60
# 12 X 6=72
# 12 X 7=84
# 12 X 8=96
# 12 X 9=108
# 12 X 10=120
# 12 X 11=132

# %%
l=['Harry','Suhail','Sachine','rahul','Sabile']
for name in l:
    if(name.startswith("S")):
        print(f"hello {name}")
# Out:
# hello Suhail
# hello Sachine
# hello Sabile

# %%
p=['Tarun','Akash',"Rajkumar","Sunah",'Taere']
for name in p:
    if(name.startswith(('T'))):
        print(f"hello {name}")
# Out:
# hello Tarun
# hello Taere
